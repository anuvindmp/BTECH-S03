# %% [markdown]
# This is a short automated vaccum cleaner agent code. There is no need to give any input from the user. It understands the envirnoment and takes the decision.Can run in any python environment such as Jupyter Notebook, Google Colab, PyCharm, etc

# %%
import random


class Environment(object):
    def __init__(self):
        self.locationCondition = {'A': '0', 'B': '0'}
        self.locationCondition['A'] = random.randint(0, 1)
        self.locationCondition['B'] = random.randint(0, 1)


class SimpleReflexVacuumAgent(Environment):
    def __init__(self, Environment):
        print (Environment.locationCondition)
        Score = 0
        vacuumLocation = random.randint(0, 1)
        if vacuumLocation == 0:
            print ("Vacuum is randomly placed at Location A.")
            print ("Location A is Dirty.") if Environment.locationCondition['A'] == 1 else print("Location A is Clean.")
            if Environment.locationCondition['A'] == 1:
                Environment.locationCondition['A'] = 0
                Score += 1
                print ("Location A has been Cleaned.")
            print ("Moving to Location B...")
            print ("Location B is Dirty.") if Environment.locationCondition['B'] == 1 else print("Location B is Clean.")
            if Environment.locationCondition['B'] == 1:
                Environment.locationCondition['B'] = 0;
                Score += 1
                print ("Location B has been Cleaned.")
            print("Environment is Clean.")

        elif vacuumLocation == 1:
            print ("Vacuum randomly placed at Location B.")
            print ("Location B is Dirty.") if Environment.locationCondition['B'] == 1 else print("Location B is Clean.")
            if Environment.locationCondition['B'] == 1:
                Environment.locationCondition['B'] = 0
                Score += 1
                print ("Location B has been Cleaned.")
            print ("Moving to Location A...")
            print ("Location A is Dirty.") if Environment.locationCondition['A'] == 1 else print("Location A is Clean.")
            if Environment.locationCondition['A'] == 1:
                Environment.locationCondition['A'] = 0;
                Score += 1
                print ("Location A has been Cleaned.")
            print("Environment is Clean.")

        print (Environment.locationCondition)
        print ("Performance Measurement: " + str(Score))


theEnvironment = Environment()
theVacuum = SimpleReflexVacuumAgent(theEnvironment)
# Out:
# {'A': 1, 'B': 0}
# Vacuum is randomly placed at Location A.
# Location A is Dirty.
# Location A has been Cleaned.
# Moving to Location B...
# Location B is Clean.
# Environment is Clean.
# {'A': 0, 'B': 0}
# Performance Measurement: 1

# %% [markdown]
# What changes you would bring about in the above code if you want the agent to consider 4 locations A,B,C,D instead of 2? Rewrite and execute the code.

# %%
import random


class Environment(object):
    def __init__(self):
        self.locationCondition = {'A': '0', 'B': '0', 'C' : '0', 'D' : '0'}
        self.locationCondition['A'] = random.randint(0, 1)
        self.locationCondition['B'] = random.randint(0, 1)
        self.locationCondition['C'] = random.randint(0, 1)
        self.locationCondition['D'] = random.randint(0, 1)


class SimpleReflexVacuumAgent(Environment):
    def __init__(self, Environment):
        print (Environment.locationCondition)
        Score = 0
        vacuumLocation = random.randint(0,3)
        if vacuumLocation == 0:
            print ("Vacuum is randomly placed at Location A.")
            print ("Location A is Dirty.") if Environment.locationCondition['A'] == 1 else print("Location A is Clean.")
            if Environment.locationCondition['A'] == 1:
                Environment.locationCondition['A'] = 0
                Score += 1
                print ("Location A has been Cleaned.")
            print ("Moving to Location B...")
            print ("Location B is Dirty.") if Environment.locationCondition['B'] == 1 else print("Location B is Clean.")
            if Environment.locationCondition['B'] == 1:
                Environment.locationCondition['B'] = 0;
                Score += 1
                print ("Location B has been Cleaned.")
            print ("Moving to Location C...")
            print ("Location C is Dirty.") if Environment.locationCondition['C'] == 1 else print("Location C is Clean.")
            if Environment.locationCondition['C'] == 1:
                Environment.locationCondition['C'] = 0;
                Score += 1
                print ("Location C has been Cleaned.")
            print ("Moving to Location D...")
            print ("Location D is Dirty.") if Environment.locationCondition['D'] == 1 else print("Location D is Clean.")
            if Environment.locationCondition['D'] == 1:
                Environment.locationCondition['D'] = 0;
                Score += 1
                print ("Location D has been Cleaned.")
            print("Environment is Clean.")

        elif vacuumLocation == 1:
            print ("Vacuum randomly placed at Location B.")
            print ("Location B is Dirty.") if Environment.locationCondition['B'] == 1 else print("Location B is Clean.")
            if Environment.locationCondition['B'] == 1:
                Environment.locationCondition['B'] = 0
                Score += 1
                print ("Location B has been Cleaned.")
            print ("Moving to Location C...")
            print ("Location C is Dirty.") if Environment.locationCondition['C'] == 1 else print("Location C is Clean.")
            if Environment.locationCondition['C'] == 1:
                Environment.locationCondition['C'] = 0;
                Score += 1
                print ("Location C has been Cleaned.")
            print ("Moving to Location D...")
            print ("Location D is Dirty.") if Environment.locationCondition['D'] == 1 else print("Location D is Clean.")
            if Environment.locationCondition['D'] == 1:
                Environment.locationCondition['D'] = 0;
                Score += 1
                print ("Location D has been Cleaned.")
            print ("Moving to Location A...")
            print ("Location A is Dirty.") if Environment.locationCondition['A'] == 1 else print("Location A is Clean.")
            if Environment.locationCondition['A'] == 1:
                Environment.locationCondition['A'] = 0;
                Score += 1
                print ("Location A has been Cleaned.")
            print("Environment is Clean.")

        elif vacuumLocation == 2:
            print ("Vacuum randomly placed at Location C.")
            print ("Location C is Dirty.") if Environment.locationCondition['C'] == 1 else print("Location C is Clean.")
            if Environment.locationCondition['C'] == 1:
                Environment.locationCondition['C'] = 0
                Score += 1
                print ("Location C has been Cleaned.")
            print ("Moving to Location D...")
            print ("Location D is Dirty.") if Environment.locationCondition['D'] == 1 else print("Location D is Clean.")
            if Environment.locationCondition['D'] == 1:
                Environment.locationCondition['D'] = 0;
                Score += 1
                print ("Location D has been Cleaned.")
            print ("Moving to Location A...")
            print ("Location A is Dirty.") if Environment.locationCondition['A'] == 1 else print("Location A is Clean.")
            if Environment.locationCondition['A'] == 1:
                Environment.locationCondition['A'] = 0;
                Score += 1
                print ("Location A has been Cleaned.")
            print ("Moving to Location B...")
            print ("Location B is Dirty.") if Environment.locationCondition['B'] == 1 else print("Location B is Clean.")
            if Environment.locationCondition['B'] == 1:
                Environment.locationCondition['B'] = 0;
                Score += 1
                print ("Location B has been Cleaned.")
            print("Environment is Clean.")
        
        elif vacuumLocation == 3:
            print ("Vacuum randomly placed at Location D.")
            print ("Location D is Dirty.") if Environment.locationCondition['D'] == 1 else print("Location D is Clean.")
            if Environment.locationCondition['D'] == 1:
                Environment.locationCondition['D'] = 0
                Score += 1
                print ("Location D has been Cleaned.")
            print ("Moving to Location A...")
            print ("Location A is Dirty.") if Environment.locationCondition['A'] == 1 else print("Location A is Clean.")
            if Environment.locationCondition['A'] == 1:
                Environment.locationCondition['A'] = 0;
                Score += 1
                print ("Location A has been Cleaned.")
            print ("Moving to Location B...")
            print ("Location B is Dirty.") if Environment.locationCondition['B'] == 1 else print("Location B is Clean.")
            if Environment.locationCondition['B'] == 1:
                Environment.locationCondition['B'] = 0;
                Score += 1
                print ("Location B has been Cleaned.")
            print ("Moving to Location C...")
            print ("Location C is Dirty.") if Environment.locationCondition['C'] == 1 else print("Location C is Clean.")
            if Environment.locationCondition['C'] == 1:
                Environment.locationCondition['C'] = 0;
                Score += 1
                print ("Location C has been Cleaned.")
            print("Environment is Clean.")
        print (Environment.locationCondition)
        print ("Performance Measurement: " + str(Score))


theEnvironment = Environment()
theVacuum = SimpleReflexVacuumAgent(theEnvironment)
# Out:
# {'A': 1, 'B': 1, 'C': 1, 'D': 0}
# Vacuum randomly placed at Location C.
# Location C is Dirty.
# Location C has been Cleaned.
# Moving to Location D...
# Location D is Clean.
# Moving to Location A...
# Location A is Dirty.
# Location A has been Cleaned.
# Moving to Location B...
# Location B is Dirty.
# Location B has been Cleaned.
# Environment is Clean.
# {'A': 0, 'B': 0, 'C': 0, 'D': 0}
# Performance Measurement: 3

# %% [markdown]
# Taking user input

# %%
import random
order = input("Enter order :")
order = order.upper()

class Environment():
    def __init__(self, order):
        self.locationCondition = {order[0]: '0', order[1]: '0', order[2] : '0', order[3] : '0'}
        self.locationCondition[order[0]] = random.randint(0, 1)
        self.locationCondition[order[1]] = random.randint(0, 1)
        self.locationCondition[order[2]] = random.randint(0, 1)
        self.locationCondition[order[3]] = random.randint(0, 1)


class SimpleReflexVacuumAgent(Environment):
    def __init__(self, Environment):
        print (Environment.locationCondition)
        Score = 0
        print (f"Vacuum is randomly placed at Location {order[0]}.")
        print (f"{order[0]} is Dirty.") if Environment.locationCondition[f'{order[0]}'] == 1 else print(f"Location {order[0]} is Clean.")
        if Environment.locationCondition[f'{order[0]}'] == 1:
            Environment.locationCondition[f'{order[0]}'] = 0;
            Score += 1
            print (f"Location {order[0]} has been Cleaned.")
        print (f"Moving to Location {order[1]}...")
        print (f"Location {order[1]} is Dirty.") if Environment.locationCondition[f'{order[1]}'] == 1 else print(f"Location {order[1]} is Clean.")
        if Environment.locationCondition[f'{order[1]}'] == 1:
            Environment.locationCondition[f'{order[1]}'] = 0;
            Score += 1
            print (f"Location {order[1]} has been Cleaned.")
        print (f"Moving to Location {order[2]}...")
        print (f"Location {order[2]} is Dirty.") if Environment.locationCondition[f'{order[2]}'] == 1 else print(f"Location {order[2]} is Clean.")
        if Environment.locationCondition[f'{order[2]}'] == 1:
            Environment.locationCondition[f'{order[2]}'] = 0;
            Score += 1
            print (f"Location {order[2]} has been Cleaned.")
        print (f"Moving to Location {order[3]}...")
        print (f"Location {order[3]} is Dirty.") if Environment.locationCondition[f'{order[3]}'] == 1 else print(f"Location {order[3]} is Clean.")
        if Environment.locationCondition[f'{order[3]}'] == 1:
            Environment.locationCondition[f'{order[3]}'] = 0;
            Score += 1
            print (f"Location {order[3]} has been Cleaned.")
        print("Environment is Clean.")

        print (Environment.locationCondition)
        print ("Performance Measurement: " + str(Score))


theEnvironment = Environment(order)
theVacuum = SimpleReflexVacuumAgent(theEnvironment)
# Out:
# {'A': 1, 'B': 0, 'D': 0, 'C': 1}
# Vacuum is randomly placed at Location A.
# A is Dirty.
# Location A has been Cleaned.
# Moving to Location B...
# Location B is Clean.
# Moving to Location D...
# Location D is Clean.
# Moving to Location C...
# Location C is Dirty.
# Location C has been Cleaned.
# Environment is Clean.
# {'A': 0, 'B': 0, 'D': 0, 'C': 0}
# Performance Measurement: 2
